# %% [markdown]
# # Exercice HR Bordeaux

# %% [markdown]
# Importations bibliothèques

# %%
import openturns as ot
import numpy as np
import openturns.viewer as otv
import pylab as pl
import openturns.viewer as viewer
from matplotlib import pylab as plt

# %% [markdown]
# ## 1. Description des données

# %%
# Importation des données
sample_HR = ot.Sample_ImportFromTextFile('Humidite-relative-Bordeaux-2018.csv', ';')

# %%
# Taille de l'échantillon
sample_HR.getSize()
# Out:
# 2779

# %%
# Histogramme de la distribution
histo_HR = ot.HistogramFactory().build(sample_HR)
histo_HR.setDescription(["Histogramme HR"])
histo_HR.drawPDF()
# Out:
# class=Graph name=Histogramme HR PDF implementation=class=GraphImplementation name=Histogramme HR PDF title=Histogramme HR PDF xTitle=Histogramme HR yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Histogramme HR PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=64 dimension=2 data=[[18.3667,0],[21,0],[21,0],[21,0.000273297],[26.2667,0.000273297],[26.2667,0],[26.2667,0],[26.2667,0.00191308],[31.5333,0.00191308],[31.5333,0],[31.5333,0],[31.5333,0.00321125],[36.8,0.00321125],[36.8,0],[36.8,0],[36.8,0.00628584],[42.0667,0.00628584],[42.0667,0],[42.0667,0],[42.0667,0.00690076],[47.3333,0.00690076],[47.3333,0],[47.3333,0],[47.3333,0.00683244],[52.6,0.00683244],[52.6,0],[52.6,0],[52.6,0.00915547],[57.8667,0.00915547],[57.8667,0],[57.8667,0],[57.8667,0.0127083],[63.1333,0.0127083],[63.1333,0],[63.1333,0],[63.1333,0.00990703],[68.4,0.00990703],[68.4,0],[68.4,0],[68.4,0.0120251],[73.6667,0.0120251],[73.6667,0],[73.6667,0],[73.6667,0.0129816],[78.9333,0.0129816],[78.9333,0],[78.9333,0],[78.9333,0.0184476],[84.2,0.0184476],[84.2,0],[84.2,0],[84.2,0.0215905],[89.4667,0.0215905],[89.4667,0],[89.4667,0],[89.4667,0.0265099],[94.7333,0.0265099],[94.7333,0],[94.7333,0],[94.7333,0.0411313],[100,0.0411313],[100,0],[100,0],[102.633,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
# Autres données
m = sample_HR.computeMean()[0]
v = sample_HR.computeVariance()[0]
q25 = sample_HR.computeQuantile(0.25)[0]
q75 = sample_HR.computeQuantile(0.75)[0]
med = sample_HR.computeMedian()[0]

print("Moyenne HR de l'échantillon : ", m)
print("Variance HR de l'échantillon : ", v)
print("Quantile à 25% de l'échantillon : ", q25)
print("Quantile à 75% de l'échantillon : ", q75)
print("Médiane de l'échantillon : ", med)
# Out:
# Moyenne HR de l'échantillon :  77.22058294350485
# Variance HR de l'échantillon :  351.3001377450075
# Quantile à 25% de l'échantillon :  64.0
# Quantile à 75% de l'échantillon :  94.0
# Médiane de l'échantillon :  83.0

# %% [markdown]
# Observations :
#
# - Pas de valeurs inférieures à 20% d'HR.
# - Valeurs comprises entre 20% et 100% d'HR.
# - Forte croissance de la densité de probabilité dans le dernier quart de l'échantillon trié.
# - Allure exponentielle de la densité de probabilité discrète.

# %% [markdown]
# ## 2. Ajustement de la loi Beta

# %%
HRBeta = ot.BetaFactory().build(sample_HR)
HRBeta
# Out:
# class=Beta name=Beta dimension=1 alpha=1.88684 beta=0.765074 a=20.9716 b=100.028

# %%
# Calcul de l'espérance et de la variance de la loi HRBeta à partir des paramètres estimés.

[alpha, beta, a, b] = HRBeta.getParameter()

m_chap = a + (b-a)*(alpha/(alpha+beta))
v_chap = (b-a)**2 * (alpha*beta/((alpha+beta)**2 * (alpha+beta+1)))

print("Moyenne de la loi HRBeta : ", m_chap)
print("Variance de la loi HRBeta : ", v_chap)
# Out:
# Moyenne de la loi HRBeta :  77.22058294350487
# Variance de la loi HRBeta :  351.3001377450076

# %% [markdown]
# Observations :
#
# - La loi HRBeta est définie sur l'intervalle $[20.97; 100.08]$ et c'est déjà ce qui avait pû être observé sur l'histogramme.
# - $\alpha$ et $\beta$ sont positifs strictements.
# - Les calculs de la moyenne et de la variance de la loi HRBeta sont sensiblement identiques à la moyenne et la variance de l'échantillon sample_HR à partir du quel on a estimé les paramètres de HRBeta.

# %%
# Fonction d'affichage pour la superposition de PDF 

def affichagePDF_HR(histo, loi, loi_ks = None):
    """
        Fonction permettant de superposer un histogramme et des densités continues.
    _______
    Parameters :
        - histo : Un histogramme.
        - loi : Une loi ajustée à partir d'un échantillon.
        - loi_ks : Une estimation de loi par lissage à noyau.  

    Returns :

    """
    histo.setDescription(['Histogramme'])
    graph = histo.drawPDF()
    loi.setDescription(['Loi ajustée'])
    graph.add(loi.drawPDF())
    graph.setXTitle("x")
    graph.setYTitle("PDF")
    graph.setTitle(
    "Ajustement de la loi à partir d'un échantillon donné")
    if(loi_ks!= None):
        loi_ks.setDescription(['Loi KernelSmoothing'])
        graph.add(loi_ks.drawPDF())
    graph.setColors(["blue", "red", "green"])
    graph.setLegendPosition('topleft')
    view = viewer.View(graph)

    return view

# %%
affichagePDF_HR(histo_HR, HRBeta)

# %% [markdown]
# Observations :
#
# L'ajustement suit la tendance et semble satisfaisant.

# %%
ot.VisualTest_DrawQQplot(sample_HR, HRBeta)
# Out:
# class=Graph name=Sample versus model QQ-plot implementation=class=GraphImplementation name=Sample versus model QQ-plot title=Sample versus model QQ-plot xTitle=HR (%) yTitle=Beta(alpha = 1.88684, beta = 0.765074, a = 20.9716, b = 100.028) axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Test line implementation=class=Curve name=Test line derived from class=DrawableImplementation name=Test line legend=Test line data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[21,21],[100,100]] color=red fillStyle=solid lineStyle=dashed pointStyle=none lineWidth=1,class=Drawable name=Data implementation=class=Cloud name=Data derived from class=DrawableImplementation name=Data legend=Data data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2779 dimension=2 data=[[21,21.9728],[22,22.7624],[25,23.3178],...,[100,100.024],[100,100.026],[100,100.028]] color=blue fillStyle=solid lineStyle=solid pointStyle=dot lineWidth=1]

# %% [markdown]
# Observations :
#
# L'ajustement semble visuellement satisfaisant, même si la queue inférieure de la disribution de l'échantillon est légèrement inférieure à celle de la distribution estimée.

# %%
# Test de Lilliefors
beta = ot.BetaFactory()
dist, testLilliefors_result = ot.FittingTest_Lilliefors(sample_HR, beta)
testLilliefors_result
# Out:
# class=TestResult name=Unnamed type=Lilliefors Beta binaryQualityMeasure=false p-value threshold=0.05 p-value=0 statistic=0.0637314 description=[Beta(alpha = 1.88684, beta = 0.765074, a = 20.9716, b = 100.028) vs sample Humidite-relative-Bordeaux-2018.csv]

# %%
dist == HRBeta
# Out:
# True

# %%
testLilliefors_result.getPValue()
# Out:
# 0.0

# %%
testLilliefors_result.getBinaryQualityMeasure()
# Out:
# False

# %% [markdown]
# Conclusion sur le test :
#
# Après avoir estimé les paramètres de la loi Beta à partir de l'échantillon, le test de Lilliefors nous indique que la loi Beta ne peut être la distribution associée à l'échantillon, malgré les bons résultats visuels obtenus à partir de la superposition des PDF et du QQPlot.

# %% [markdown]
# ## 3. Distribution de l'estimation des paramètres

# %%
fittedRes = ot.BetaFactory().buildEstimator(sample_HR)
fittedRes
# Out:
# class=DistributionFactoryResult distribution=class=Beta name=Beta dimension=1 alpha=1.88684 beta=0.765074 a=20.9716 b=100.028 parameterDistribution=class=KernelMixture name=KernelMixture kernel=class=Normal name=Normal dimension=1 mean=class=Point name=Unnamed dimension=1 values=[0] sigma=class=Point name=Unnamed dimension=1 values=[1] correlationMatrix=class=CorrelationMatrix dimension=1 implementation=class=MatrixImplementation name=Unnamed rows=1 columns=1 values=[1] bandwidth=class=Point name=Unnamed dimension=4 values=[0.0431894,0.0145505,0.417014,0.000149897] sample=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=4 data=[[1.88058,0.766058,20.9716,100.028],[1.88675,0.78847,20.9716,100.028],[1.74596,0.731651,21.972,100.028],[1.77696,0.744755,21.972,100.028],[1.76846,0.744844,21.972,100.028],[1.85666,0.764254,20.9716,100.028],[1.82406,0.756626,20.9716,100.028],[1.88861,0.773968,20.9716,100.028],[1.9543,0.787413,20.9716,100.028],[1.85984,0.753091,20.9716,100.028],[1.76713,0.752688,21.972,100.028],[1.98946,0.793368,20.9716,100.028],[1.67497,0.760963,24.973,100.027],[1.89066,0.779573,20.9716,100.028],[1.90591,0.761937,20.9716,100.028],[2.0151,0.766736,20.9716,100.028],[1.87753,0.762331,20.9716,100.028],[1.80159,0.767622,20.9716,100.028],[1.8782,0.765225,20.9716,100.028],[1.84511,0.768789,20.9716,100.028],[1.92225,0.776807,20.9716,100.028],[1.85961,0.773558,21.972,100.028],[1.89865,0.748525,20.9716,100.028],[1.87654,0.781799,20.9716,100.028],[1.70628,0.735685,24.973,100.027],[1.91253,0.781111,20.9716,100.028],[1.88249,0.742481,21.972,100.028],[1.65242,0.714542,24.973,100.027],[1.83384,0.751061,20.9716,100.028],[1.8645,0.776084,20.9716,100.028],[1.76337,0.724315,21.972,100.028],[1.8275,0.747818,20.9716,100.028],[1.73663,0.714265,20.9716,100.028],[1.6775,0.714315,24.973,100.027],[1.83391,0.752015,20.9716,100.028],[1.77793,0.743532,21.972,100.028],[1.8625,0.74816,20.9716,100.028],[1.95471,0.777075,20.9716,100.028],[1.86214,0.781274,20.9716,100.028],[1.79121,0.738387,20.9716,100.028],[1.76446,0.745562,21.972,100.028],[1.95451,0.799121,20.9716,100.028],[1.82833,0.747164,21.972,100.028],[1.88175,0.739054,20.9716,
PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1000 dimension=2 data=[[0.25,1.69536e-218],[0.251001,1.49012e-217],[0.252002,1.30355e-216],...,[1.248,4.04645e-196],[1.249,5.1417e-197],[1.25,6.50256e-198]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
# PDF du minimum
dist_param.drawMarginal1DPDF(2, 15.0, 30.0, 1000)
# Out:
# class=Graph name=pdf as a function of v2 implementation=class=GraphImplementation name=pdf as a function of v2 title=[v0,v1,v2,v3]->v2 component PDF xTitle=v2 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=v2 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1000 dimension=2 data=[[15,1.78692e-45],[15.015,2.99052e-45],[15.03,4.99833e-45],...,[29.97,5.90071e-14],[29.985,4.55271e-14],[30,3.50811e-14]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
# PDF du maximum
dist_param.drawMarginal1DPDF(3, 99.0, 101.0, 1000)
# Out:
# class=Graph name=pdf as a function of v3 implementation=class=GraphImplementation name=pdf as a function of v3 title=[v0,v1,v2,v3]->v3 component PDF xTitle=v3 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=v3 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1000 dimension=2 data=[[99,0],[99.002,0],[99.004,0],...,[100.996,0],[100.998,0],[101,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %% [markdown]
# Intervalles de confiance (à vérif)

# %%
confInt = dist_param.computeBilateralConfidenceInterval(0.95)
confInt
# Out:
# class=Interval name=Unnamed dimension=4 lower bound=class=Point name=Unnamed dimension=4 values=[1.59624,0.69322,20.0239,100.026] upper bound=class=Point name=Unnamed dimension=4 values=[2.0357,0.818241,26.7231,100.029] finite lower bound=[1,1,1,1] finite upper bound=[1,1,1,1]

# %% [markdown]
# Longueur des intervalles de confiance

# %%
longueur_int = confInt.getUpperBound() - confInt.getLowerBound()

# %%
longueur_int[0]
# Out:
# 0.43946469664077825

# %%
longueur_int[1]
# Out:
# 0.12502081563115963

# %%
longueur_int[2]
# Out:
# 6.699161646883947

# %%
longueur_int[3]
# Out:
# 0.00240803797524336

# %% [markdown]
# ## 4. Recherche de la meilleure loi ajustée au sens du critère BIC

# %%
# Création d'une collection de distributions
distcoll = ot.DistributionFactory_GetContinuousUniVariateFactories()

# %%
# Taille de la collection
distcoll.getSize()
# Out:
# 31

# %%
# Test modèle BIC
best_model, best_BIC = ot.FittingTest_BestModelBIC(sample_HR, distcoll)

# %%
# Meilleur modèle (selon critère BIC)
best_model
# Out:
# class=Beta name=Beta dimension=1 alpha=1.88684 beta=0.765074 a=20.9716 b=100.028

# %%
best_model == HRBeta
# Out:
# True

# %% [markdown]
# Observations :
#
# Selon le critère BIC, c'est encore la loi Beta qui approche le mieux la distribution de notre échantillon. On remarque que c'est exactement la même distribution que celle obtenue par méthode des moments et non-validée par le test de Lilliefors.

# %% [markdown]
# ## 5. Méthode d'estimation à noyau

# %%
ks_distHR = ot.KernelSmoothing().build(sample_HR)
ks_distHR.setDescription(["HR par KS"])

# %%
ks_distHR.drawPDF()
# Out:
# class=Graph name=pdf as a function of HR par KS implementation=class=GraphImplementation name=pdf as a function of HR par KS title= xTitle=HR par KS yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=HR par KS PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[
0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %% [markdown]
# Observations :
#
# Les observations sont sensiblement identiques à celles de la figure précédente à la différence qu'une troncature a été effectuée sur le bord droit de manière à observer une densité de probabilité sur des valeurs comprises entre $27\%$ et $100\%$.

# %% [markdown]
# Test de Kolmogorov :
#
# Comme on fait l'hypothèse que l'on connaît la loi, via l'estimation non-paramétrique de la distribution de l'échantillon, on est bien dans le cadre du test de Kolmogorov.

# %%
# Réalisation du test de Kolmogorov-Smirnov
testKolmogorov_result = ot.FittingTest.Kolmogorov(sample_HR, ks_distHR2)

# %%
# P-Valeur
testKolmogorov_result.getPValue()
# Out:
# 0.007795322766446515

# %%
# Résultat
testKolmogorov_result.getBinaryQualityMeasure()
# Out:
# False

# %% [markdown]
# Le résultat du test n'est pas concluant, ce qui est dérangeant puisqu'aucun paramêtre n'a été estimé et que la distribution prise pour réaliser le test a été construire à partir d'une méthode de lissage à noyau. Donc cette distribution est indépendante de la taille de l'échantillon sample_HR.

# %% [markdown]
# ## 6. Synthèse

# %%
affichagePDF_HR(histo_HR, HRBeta, ks_distHR2)

# %% [markdown]
# ## 7. Estimation d'une loi Beta par la méthode du maximum de vraisemblance

# %%
# Estimation des paramètres

def Beta_MaxLikelihood(Sample, epsilon):
    """
        Estimation des paramètres d'une loi Beta, à partir d'un échantillon, par maximum de vraisemblance.

    Parameters : 
        - Sample : L'échantillon dont on dispose.

    Returns : 
        - Beta : Distribution Beta estimée par maximum de vraisemblance.
    """
    
    # Minimum et maximum
    a = Sample.getMin()[0]* (1-epsilon)
    b = Sample.getMax()[0]* (1+epsilon)

    # Alpha et beta
    factory = ot.MaximumLikelihoodFactory(ot.Beta())
    factory.setKnownParameter([a, b], [2, 3])
    bounds_lower = [ot.SpecFunc.MinScalar] * 2
    bounds_upper = [1.0] * 2  # Disable anyway (ignored)
    interval = ot.Interval(bounds_lower, bounds_upper, [True] * 2, [False] * 2)
    factory.setOptimizationBounds(interval) 

    Beta = factory.build(Sample)

    return Beta

# %%
HRBeta_ML14 = Beta_MaxLikelihood(sample_HR, 1e-14)
HRBeta_ML14
# Out:
# class=Beta name=Beta dimension=1 alpha=2 beta=2 a=21 b=100

# %%
HRBeta_ML15 = Beta_MaxLikelihood(sample_HR, 1e-15)
HRBeta_ML15
# Out:
# class=Beta name=Beta dimension=1 alpha=1.45141 beta=0.552986 a=21 b=100

# %%
HRBeta_ML14.drawPDF()
# Out:
# class=Graph name=pdf as a function of HR (%) implementation=class=GraphImplementation name=pdf as a function of HR (%) title= xTitle=HR (%) yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=HR (%) PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[-12.192,0],[-11.0562,0],[-9.92035,0],[-8.78453,0],[-7.64872,0],[-6.51291,0],[-5.3771,0],[-4.24129,0],[-3.10547,0],[-1.96966,0],[-0.83385,0],[0.301962,0],[1.43777,0],[2.57359,0],[3.7094,0],[4.84521,0],[5.98102,0],[7.11683,0],[8.25265,0],[9.38846,0],[10.5243,0],[11.6601,0],[12.7959,0],[13.9317,0],[15.0675,0],[16.2033,0],[17.3391,0],[18.475,0],[19.6108,0],[20.7466,0],[21.8824,0.000838841],[23.0182,0.0018907],[24.154,0.00291116],[25.2898,0.00390022],[26.4256,0.00485789],[27.5615,0.00578415],[28.6973,0.00667902],[29.8331,0.00754248],[30.9689,0.00837455],[32.1047,0.00917522],[33.2405,0.00994449],[34.3763,0.0106824],[35.5121,0.0113888],[36.6479,0.0120639],[37.7838,0.0127076],[38.9196,0.0133199],[40.0554,0.0139007],[41.1912,0.0144502],[42.327,0.0149683],[43.4628,0.015455],[44.5986,0.0159103],[45.7344,0.0163341],[46.8703,0.0167266],[48.0061,0.0170877],[49.1419,0.0174174],[50.2777,0.0177157],[51.4135,0.0179826],[52.5493,0.0182181],[53.6851,0.0184222],[54.8209,0.0185949],[55.9568,0.0187362],[57.0926,0.018846],[58.2284,0.0189245],[59.3642,0.0189716],[60.5,0.0189873],[61.6358,0.0189716],[62.7716,0.0189245],[63.9074,0.018846],[65.0432,0.0187362],[66.1791,0.0185949],[67.3149,0.0184222],[68.4507,0.0182181],[69.5865,0.0179826],[70.7223,0.0177157],[71.8581,0.0174174],[72.9939,0.0170877],[74.1297,0.0167266],[75.2656,0.0163341],[76.4014,0.0159103],[77.5372,0.015455],[78.673,0.0149683],[79.8088,0.0144502],[80.9446,0.0139007],[82.0804,0.0133199],[83.2162,0.0127076],[84.3521,0.0120639],[85.4879,0.0113888],[86.6237,0.0106824],[87.7595,0.00994449],[88.8953,0.00917522],[90.0311,0.00837455],[91.1669,0.00754248],[92.3027,0.00667902],[93.4385,0.00578415],[94.5744,0.00485789],[95.7102,0.00390022],[96.846,0.00291116],[97.9818,0.0018907],[99.1176,0.000838841],[100.253,0],[101.389,0],[102.525,0],[103.661,0],[104.797,0],[105.932,0],[107.068,0],[108.204,0],[109.34,0],[110.476,0],[111.612,0],[112.747,0],[113.883,0],[115.019,0],[116.155,0],[117.291,0],[118.426,0],[119.562,0],[120.698,0],[121.834,0],[122.97,0],[124.105,0],[125.241,0],[126.377,0],[127.513,0],[128.649,0],[129.785,0],[130.92,0],[132.056,0],[133.192,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
ot.VisualTest_DrawQQplot(sample_HR, HRBeta_ML14)
# Out:
# class=Graph name=Sample versus model QQ-plot implementation=class=GraphImplementation name=Sample versus model QQ-plot title=Sample versus model QQ-plot xTitle=HR (%) yTitle=Beta(alpha = 2, beta = 2, a = 21, b = 100) axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Test line implementation=class=Curve name=Test line derived from class=DrawableImplementation name=Test line legend=Test line data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[21,21],[100,100]] color=red fillStyle=solid lineStyle=dashed pointStyle=none lineWidth=1,class=Drawable name=Data implementation=class=Cloud name=Data derived from class=DrawableImplementation name=Data legend=Data data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2779 dimension=2 data=[[21,21.6134],[22,22.0645],[25,22.376],...,[100,98.624],[100,98.9355],[100,99.3866]] color=blue fillStyle=solid lineStyle=solid pointStyle=dot lineWidth=1]

# %%
HRBeta_ML15.drawPDF()
# Out:
# class=Graph name=pdf as a function of HR (%) implementation=class=GraphImplementation name=pdf as a function of HR (%) title= xTitle=HR (%) yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=HR (%) PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[
=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2779 dimension=2 data=[[21,21.3418],[22,21.7279],[25,22.0343],...,[100,99.9998],[100,99.9999],[100,100]] color=blue fillStyle=solid lineStyle=solid pointStyle=dot lineWidth=1]

# %% [markdown]
# QQ-Plot

# %%
affichagePDF_HR(histo_HR, HRBeta_ML15)

# %% [markdown]
# CONCLURE!!!

# %% [markdown]
# ## 8 Dessin de la log-vraissemblance

# %%
def log_likelihood(theta):
    alpha, beta= theta
    epsilon = 1e-15
    n = sample_HR.getSize()
    a_chap = sample_HR.getMin() * (1-epsilon)
    b_chap = sample_HR.getMax() * (1+epsilon)
    return [(alpha-1)*np.sum(np.log(sample_HR-a_chap)) + (beta-1)*np.sum(np.log((-1)*sample_HR+b_chap))- n*(alpha+beta-1)*np.log(b_chap-a_chap)[0] - n*np.log(ot.SpecFunc_Beta(alpha,beta))]
    
log_likelihood_Py = ot.PythonFunction(2, 1, log_likelihood)
#log_likelihood_Py = ot.MemoizeFunction(log_likelihood_Py)

# %%
X = [2.0, 2.0]
Y = log_likelihood_Py(X)
print(Y)
# Out:
# [-14346.1]

# %%
graph_likelihood = log_likelihood_Py.draw([0,1],[0,1],[100,100])
View(graph_likelihood).show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-c07eb034283e> in log_likelihood(theta)
#       5     a_chap = sample_HR.getMin() * (1-epsilon)
#       6     b_chap = sample_HR.getMax() * (1+epsilon)
# ----> 7     return [(alpha-1)*np.sum(np.log(sample_HR-a_chap)) + (beta-1)*np.sum(np.log((-1)*sample_HR+b_chap))- n*(alpha+beta-1)*np.log(b_chap-a_chap)[0] - n*np.log(ot.SpecFunc_Beta(alpha,beta))]
#       8
#       9 log_likelihood_Py = ot.PythonFunction(2, 1, log_likelihood)
#
# ~/anaconda3/lib/python3.8/site-packages/openturns/func.py in SpecFunc_Beta(a, b)
#    5505     result : float
#    5506     """
# -> 5507     return _func.SpecFunc_Beta(a, b)
#    5508
#    5509 def SpecFunc_IncompleteBeta(a, b, x, tail=False):
#
# TypeError: InvalidArgumentException : Error: cannot compute the LogBeta function when a or b is nonpositive, a=0, b=1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-163-333ab6055fec> in <module>
# ----> 1 graph_likelihood = log_likelihood_Py.draw([0,1],[0,1],[100,100])
#       2 View(graph_likelihood).show()
#
# ~/anaconda3/lib/python3.8/site-packages/openturns/func.py in draw(self, *args)
#   11384         >>> View(graph).show()
#   11385         """
# > 11386         return _func.Function_draw(self, *args)
#   11387
#   11388     def __init__(self, *args):
#
# RuntimeError: InternalException : Python exception: TypeError: InvalidArgumentException : Error: cannot compute the LogBeta function when a or b is nonpositive, a=0, b=1

# %%
theta = [2,2]
a,b = theta

# %%
alpha = np.array([1,2])
beta = np.array([4,5])
# Out:
# array([ 0., 10.,  0.])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-e6478affcb1b> in <module>
# ----> 1 ot.SpecFunc_Beta(alpha,beta)
#
# ~/anaconda3/lib/python3.8/site-packages/openturns/func.py in SpecFunc_Beta(a, b)
#    5505     result : float
#    5506     """
# -> 5507     return _func.SpecFunc_Beta(a, b)
#    5508
#    5509 def SpecFunc_IncompleteBeta(a, b, x, tail=False):
#
# TypeError: in method 'SpecFunc_Beta', argument 2 of type 'OT::Scalar'
